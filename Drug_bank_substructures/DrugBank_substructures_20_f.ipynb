# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_seq = pd.read_csv('smi.csv', header=None)

# %%
df_seq.head()
# Out:
#                                                    0
# 0                                             smiles
# 1  CC[C@H](C)[C@H](NC(=O)[C@H](CCC(O)=O)NC(=O)[C@...
# 2  CCNC(=O)[C@@H]1CCCN1C(=O)[C@H](CCCNC(N)=N)NC(=...
# 3  CC(C)C[C@H](NC(=O)[C@@H](COC(C)(C)C)NC(=O)[C@H...
# 4  NC(=O)CC[C@@H]1NC(=O)[C@H](CC2=CC=CC=C2)NC(=O)...

# %%
len(df_seq)
# Out:
# 8289

# %%
df_seq[0].values[1]
# Out:
# 'CC[C@H](C)[C@H](NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CCC(O)=O)NC(=O)[C@H](CC1=CC=CC=C1)NC(=O)[C@H](CC(O)=O)NC(=O)CNC(=O)[C@H](CC(N)=O)NC(=O)CNC(=O)CNC(=O)CNC(=O)CNC(=O)[C@@H]1CCCN1C(=O)[C@H](CCCNC(N)=N)NC(=O)[C@@H]1CCCN1C(=O)[C@H](N)CC1=CC=CC=C1)C(=O)N1CCC[C@H]1C(=O)N[C@@H](CCC(O)=O)C(=O)N[C@@H](CCC(O)=O)C(=O)N[C@@H](CC1=CC=C(O)C=C1)C(=O)N[C@@H](CC(C)C)C(O)=O'

# %%
freq_codes = []

# %%
import os
import sys
import inspect
import codecs
import re
import copy
import argparse
import warnings
from collections import defaultdict, Counter

# %%
def get_vocabulary(fobj, is_dict=False):
#     Read text and return dictionary that encodes vocabulary
    vocab = Counter()
    for i, line in enumerate(fobj):
        if is_dict:
            try:
                word, count = line.strip('\r\n ').split(' ')
            except:
                print('Failed reading vocabulary file at line {0}: {1}'.format(i, line))
                sys.exit(1)
            vocab[word] += int(count)
        else:
            for word in line.strip('\r\n ').split(' '):
                if word:
                    vocab[word] += 1
        
    
    vocab = Counter()
    for word in fobj:
        vocab[word] += 1
    return vocab

# %%
def update_pair_statistics(pair, changed, stats, indices):
    """Minimally update the indices and frequency of symbol pairs
    if we merge a pair of symbols, only pairs that overlap with occurrences
    of this pair are affected, and need to be updated.
    """
    stats[pair] = 0
    indices[pair] = defaultdict(int)
    first, second = pair
    new_pair = first+second
    for j, word, old_word, freq in changed:

        # find all instances of pair, and update frequency/indices around it
        i = 0
        while True:
            # find first symbol
            try:
                i = old_word.index(first, i)
            except ValueError:
                break
            # if first symbol is followed by second symbol, we've found an occurrence of pair (old_word[i:i+2])
            if i < len(old_word)-1 and old_word[i+1] == second:
                # assuming a symbol sequence "A B C", if "B C" is merged, reduce the frequency of "A B"
                if i:
                    prev = old_word[i-1:i+1]
                    stats[prev] -= freq
                    indices[prev][j] -= 1
                if i < len(old_word)-2:
                    # assuming a symbol sequence "A B C B", if "B C" is merged, reduce the frequency of "C B".
                    # however, skip this if the sequence is A B C B C, because the frequency of "C B" will be reduced by the previous code block
                    if old_word[i+2] != first or i >= len(old_word)-3 or old_word[i+3] != second:
                        nex = old_word[i+1:i+3]
                        stats[nex] -= freq
                        indices[nex][j] -= 1
                i += 2
            else:
                i += 1

        i = 0
        while True:
            try:
                # find new pair
                i = word.index(new_pair, i)
            except ValueError:
                break
            # assuming a symbol sequence "A BC D", if "B C" is merged, increase the frequency of "A BC"
            if i:
                prev = word[i-1:i+1]
                stats[prev] += freq
                indices[prev][j] += 1
            # assuming a symbol sequence "A BC B", if "B C" is merged, increase the frequency of "BC B"
            # however, if the sequence is A BC BC, skip this step because the count of "BC BC" will be incremented by the previous code block
            if i < len(word)-1 and word[i+1] != new_pair:
                nex = word[i:i+2]
                stats[nex] += freq
                indices[nex][j] += 1
            i += 1

# %%
def get_pair_statistics(vocab):
    """Count frequency of all symbol pairs, and create index"""

    # data structure of pair frequencies
    stats = defaultdict(int)

    #index from pairs to words
    indices = defaultdict(lambda: defaultdict(int))

    for i, (word, freq) in enumerate(vocab):
        prev_char = word[0]
        for char in word[1:]:
            stats[prev_char, char] += freq
            indices[prev_char, char][i] += 1
            prev_char = char

    return stats, indices


def replace_pair(pair, vocab, indices):
    """Replace all occurrences of a symbol pair ('A', 'B') with a new symbol 'AB'"""
    first, second = pair
    pair_str = ''.join(pair)
    pair_str = pair_str.replace('\\','\\\\')
    changes = []
    pattern = re.compile(r'(?<!\S)' + re.escape(first + ' ' + second) + r'(?!\S)')
    if sys.version_info < (3, 0):
        iterator = indices[pair].iteritems()
    else:
        iterator = indices[pair].items()
    for j, freq in iterator:
        if freq < 1:
            continue
        word, freq = vocab[j]
        new_word = ' '.join(word)
        new_word = pattern.sub(pair_str, new_word)
        new_word = tuple(new_word.split(' '))

        vocab[j] = (new_word, freq)
        changes.append((j, new_word, word, freq))

    return changes

def prune_stats(stats, big_stats, threshold):
    """Prune statistics dict for efficiency of max()
    The frequency of a symbol pair never increases, so pruning is generally safe
    (until we the most frequent pair is less frequent than a pair we previously pruned)
    big_stats keeps full statistics for when we need to access pruned items
    """
    for item,freq in list(stats.items()):
        if freq < threshold:
            del stats[item]
            if freq < 0:
                big_stats[item] += freq
            else:
                big_stats[item] = freq


def learn_bpe(infile, outfile, num_symbols, min_frequency=2, verbose=False, is_dict=False, total_symbols=False):
    """Learn num_symbols BPE operations from vocabulary, and write to outfile.
    """

    # version 0.2 changes the handling of the end-of-word token ('</w>');
    # version numbering allows bckward compatibility
    outfile.write('#version: 0.2\n')

    vocab = get_vocabulary(infile, is_dict)
    vocab = dict([(tuple(x[:-1])+(x[-1]+'</w>',) ,y) for (x,y) in vocab.items()])
    sorted_vocab = sorted(vocab.items(), key=lambda x: x[1], reverse=True)

    stats, indices = get_pair_statistics(sorted_vocab)
    big_stats = copy.deepcopy(stats)

    if total_symbols:
        uniq_char_internal = set()
        uniq_char_final = set()
        for word in vocab:
            for char in word[:-1]:
                uniq_char_internal.add(char)
            uniq_char_final.add(word[-1])
        sys.stderr.write('Number of word-internal characters: {0}\n'.format(len(uniq_char_internal)))
        sys.stderr.write('Number of word-final characters: {0}\n'.format(len(uniq_char_final)))
        sys.stderr.write('Reducing number of merge operations by {0}\n'.format(len(uniq_char_internal) + len(uniq_char_final)))
        num_symbols -= len(uniq_char_internal) + len(uniq_char_final)
        for i in uniq_char_internal:
            vocab_index2units2freq[i] = 0

    # threshold is inspired by Zipfian assumption, but should only affect speed
    threshold = max(stats.values()) / 10
    for i in range(num_symbols):
        if stats:
            most_frequent = max(stats, key=lambda x: (stats[x], x))

        # we probably missed the best pair because of pruning; go back to full statistics
        if not stats or (i and stats[most_frequent] < threshold):
            prune_stats(stats, big_stats, threshold)
            stats = copy.deepcopy(big_stats)
            most_frequent = max(stats, key=lambda x: (stats[x], x))
            # threshold is inspired by Zipfian assumption, but should only affect speed
            threshold = stats[most_frequent] * i/(i+10000.0)
            prune_stats(stats, big_stats, threshold)

        if stats[most_frequent] < min_frequency:
            sys.stderr.write('no pair has frequency >= {0}. Stopping\n'.format(min_frequency))
            break
        
        #essential
        s1 = most_frequent[0].replace('</w>','')
        s2 = most_frequent[1].replace('</w>','')
        
        vocab_index2units2freq[s1+s2] = stats[most_frequent]
        
        if verbose:
            sys.stderr.write('pair {0}: {1} {2} -> {1}{2} (frequency {3})\n'.format(i, most_frequent[0], most_frequent[1], stats[most_frequent]))
        outfile.write('{0} {1}\n'.format(*most_frequent))
        freq_codes.append(most_frequent)
        changes = replace_pair(most_frequent, sorted_vocab, indices)
        update_pair_statistics(most_frequent, changes, stats, indices)
        stats[most_frequent] = 0
        if not i % 100:
            prune_stats(stats, big_stats, threshold)

# %%
vocab_index2units2freq = {}
seq = (df_seq[0].values)
output = open('drug_codes_drug_bank_freq_100.txt', 'w+')
learn_bpe(seq, output, 30000, min_frequency=20, verbose=True, is_dict=False, total_symbols=True)
# Out:
# Number of word-internal characters: 54
# Number of word-final characters: 15
# Reducing number of merge operations by 69
# pair 0: = C -> =C (frequency 35095)
# pair 1: O ) -> O) (frequency 24715)
# pair 2: C C -> CC (frequency 22096)
# pair 3: [ C -> [C (frequency 18298)
# pair 4: [C @ -> [C@ (frequency 18243)
# pair 5: C ( -> C( (frequency 17635)
# pair 6: H ] -> H] (frequency 17560)
# pair 7: C =C -> C=C (frequency 15971)
# pair 8: = O) -> =O) (frequency 13470)
# pair 9: [C@ @ -> [C@@ (frequency 8814)
# pair 10: C ) -> C) (frequency 8323)
# pair 11: C 1 -> C1 (frequency 7783)
# pair 12: C( =O) -> C(=O) (frequency 7721)
# pair 13: H] ( -> H]( (frequency 7369)
# pair 14: [ H] -> [H] (frequency 6646)
# pair 15: =C C=C -> =CC=C (frequency 6103)
# pair 16: ( O) -> (O) (frequency 4611)
# pair 17: [H] ) -> [H]) (frequency 4369)
# pair 18: C 2 -> C2 (frequency 4363)
# pair 19: ( [H]) -> ([H]) (frequency 4110)
# pair 20: 1 ) -> 1) (frequency 3996)
# pair 21: [C@ H]( -> [C@H]( (frequency 3968)
# pair 22: = N -> =N (frequency 3946)
# pair 23: =C ( -> =C( (frequency 3910)
# pair 24: [C@@ ] -> [C@@] (frequency 3798)
# pair 25: [C@ ] -> [C@] (frequency 3572)
# pair 26: ( C) -> (C) (frequency 3428)
# pair 27: [C@@ H]( -> [C@@H]( (frequency 3399)
# pair 28: C1 =CC=C -> C1=CC=C (frequency 2826)
# pair 29: ( =O) -> (=O) (frequency 2727)
# pair 30: C(=O) N -> C(=O)N (frequency 2638)
# pair 31: CC CC -> CCCC (frequency 2601)
# pair 32: 2 ) -> 2) (frequency 2476)
# pair 33: C( O) -> C(O) (frequency 2326)
# pair 34: N ) -> N) (frequency 2254)
# pair 35: = O</w> -> =O</w> (frequency 2248)
# pair 36: H] 1 -> H]1 (frequency 2006)
# pair 37: F ) -> F) (frequency 2002)
# pair 38: ( CC -> (CC (frequency 1975)
# pair 39: N C(=O) -> NC(=O) (frequency 1947)
# pair 40: C=C 1) -> C=C1) (frequency 1873)
# pair 41: C1 =C -> C1=C (frequency 1784)
# pair 42: C O -> CO (frequency 1755)
# pair 43: C N -> CN (frequency 1702)
# pair 44: C( C) -> C(C) (frequency 1580)
# pair 45: [C@@] 1 -> [C@@]1 (frequency 1537)
# pair 46: CC 1 -> CC1 (frequency 1507)
# pair 47: C 3 -> C3 (frequency 1481)
# pair 48: [C@] 1 -> [C@]1 (frequency 1468)
# pair 49: =C 1 -> =C1 (frequency 1385)
# pair 50: C=C 1</w> -> C=C1</w> (frequency 1347)
# pair 51: [C@H]( O) -> [C@H](O) (frequency 1235)
# pair 52: ( C -> (C (frequency 1215)
# pair 53: [C@@H]( O) -> [C@@H](O) (frequency 1098)
# pair 54: l ) -> l) (frequency 1092)
# pair 55: N =C -> N=C (frequency 1071)
# pair 56: [C@ H]1 -> [C@H]1 (frequency 1044)
# pair 57: C2 =CC=C -> C2=CC=C (frequency 1022)
# pair 58: N 1 -> N1 (frequency 1017)
# pair 59: C1=CC=C ( -> C1=CC=C( (frequency 1014)
# pair 60: 3 ) -> 3) (frequency 1001)
# pair 61: C=C 1 -> C=C1 (frequency 988)
# pair 62: [C@@ H]1 -> [C@@H]1 (frequency 962)
# pair 63: O CC -> OCC (frequency 958)
# pair 64: [C@] ([H]) -> [C@]([H]) (frequency 956)
# pair 65: C =N -> C=N (frequency 954)
# pair 66: C(O) =O</w> -> C(O)=O</w> (frequency 938)
# pair 67: C2 =C( -> C2=C( (frequency 934)
# pair 68: C=C 2) -> C=C2) (frequency 923)
# pair 69: H] 2 -> H]2 (frequency 875)
# pair 70: C1 =N -> C1=N (frequency 850)
# pair 71: C1 =C( -> C1=C( (frequency 850)
# pair 72: - ] -> -] (frequency 848)
# pair 73: C2 =C -> C2=C (frequency 834)
# pair 74: P (O) -> P(O) (frequency 832)
# pair 75: [C@@] ([H]) -> [C@@]([H]) (frequency 830)
# pair 76: C( =C -> C(=C (frequency 805)
# pair 77: [ O -> [O (frequency 778)
# pair 78: C l) -> Cl) (frequency 752)
# pair 79: O C) -> OC) (frequency 751)
# pair 80: O C(=O) -> OC(=O) (frequency 750)
# pair 81: C( N) -> C(N) (frequency 748)
# pair 82: C(O) =O) -> C(O)=O) (frequency 737)
# pair 83: [O -] -> [O-] (frequency 724)
# pair 84: C=C ( -> C=C( (frequency 701)
# pair 85: CC N -> CCN (frequency 689)
# pair 86: (O) =O) -> (O)=O) (frequency 682)
# pair 87: + ] -> +] (frequency 679)
# pair 88: [O-] ) -> [O-]) (frequency 657)
# pair 89: [ N -> [N (frequency 655)
# pair 90: [H] [C@@]1 -> [H][C@@]1 (frequency 651)
# pair 91: CC1 =CC=C -> CC1=CC=C (frequency 635)
# pair 92: C O) -> CO) (frequency 632)
# pair 93: C( F) -> C(F) (frequency 627)
# pair 94: CC (C) -> CC(C) (frequency 620)
# pair 95: C=C 2 -> C=C2 (frequency 615)
# pair 96: ( F) -> (F) (frequency 615)
# pair 97: O [C@H]( -> O[C@H]( (frequency 598)
# pair 98: S (=O) -> S(=O) (frequency 589)
# pair 99: [H] [C@]1 -> [H][C@]1 (frequency 588)
# pair 100: S(=O) (=O) -> S(=O)(=O) (frequency 573)
# pair 101: CN 1 -> CN1 (frequency 560)
# pair 102: \ C=C -> \C=C (frequency 543)
# pair 103: [C@@] 2 -> [C@@]2 (frequency 543)
# pair 104: C2 =C1 -> C2=C1 (frequency 537)
# pair 105: N =C( -> N=C( (frequency 506)
# pair 106: [C@ H]2 -> [C@H]2 (frequency 505)
# pair 107: N 2 -> N2 (frequency 488)
# pair 108: O C -> OC (frequency 486)
# pair 109: CC C -> CCC (frequency 485)
# pair 110: CC (=O) -> CC(=O) (frequency 476)
# pair 111: C1=CC=C( C=C1) -> C1=CC=C(C=C1) (frequency 467)
# pair 112: ( [O-]) -> ([O-]) (frequency 465)
# pair 113: [C@@]1 ([H]) -> [C@@]1([H]) (frequency 451)
# pair 114: [N +] -> [N+] (frequency 449)
# pair 115: ( N) -> (N) (frequency 448)
# pair 116: NC(=O) [C@H]( -> NC(=O)[C@H]( (frequency 444)
# pair 117: H] 3 -> H]3 (frequency 434)
# pair 118: [C@]1 ([H]) -> [C@]1([H]) (frequency 431)
# pair 119: C( =N -> C(=N (frequency 430)
# pair 120: [C@]([H]) (O) -> [C@]([H])(O) (frequency 417)
# pair 121: C [C@H]( -> C[C@H]( (frequency 414)
# pair 122: CCCC CCCC -> CCCCCCCC (frequency 412)
# pair 123: CC1 =C -> CC1=C (frequency 407)
# pair 124: C2 =N -> C2=N (frequency 406)
# pair 125: [C@@H]( C) -> [C@@H](C) (frequency 398)
# pair 126: C1=CC=C C=C1</w> -> C1=CC=CC=C1</w> (frequency 398)
# pair 127: C1=C C( -> C1=CC( (frequency 396)
# pair 128: C(C) (C) -> C(C)(C) (frequency 395)
# pair 129: ( O -> (O (frequency 387)
# pair 130: 2 CC -> 2CC (frequency 384)
# pair 131: C3 =C -> C3=C (frequency 382)
# pair 132: P(O) (O)=O) -> P(O)(O)=O) (frequency 373)
# pair 133: [C@@ H]2 -> [C@@H]2 (frequency 370)
# pair 134: CC 2 -> CC2 (frequency 366)
# pair 135: C(F) (F) -> C(F)(F) (frequency 364)
# pair 136: [C@@]2 ([H]) -> [C@@]2([H]) (frequency 363)
# pair 137: N ( -> N( (frequency 361)
# pair 138: [H] [C@@] -> [H][C@@] (frequency 354)
# pair 139: (C O) -> (CO) (frequency 350)
# pair 140: C3 =C( -> C3=C( (frequency 349)
# pair 141: C( N -> C(N (frequency 348)
# pair 142: C1 =O</w> -> C1=O</w> (frequency 346)
# pair 143: C3 =CC=C -> C3=CC=C (frequency 344)
# pair 144: CCN (CC -> CCN(CC (frequency 341)
# pair 145: C=C 3) -> C=C3) (frequency 334)
# pair 146: C(=O)N [C@@H]( -> C(=O)N[C@@H]( (frequency 334)
# pair 147: P(O) (=O) -> P(O)(=O) (frequency 333)
# pair 148: [C@H]( C) -> [C@H](C) (frequency 328)
# pair 149: C(N) =N -> C(N)=N (frequency 327)
# pair 150: (C l) -> (Cl) (frequency 323)
# pair 151: =C 1</w> -> =C1</w> (frequency 317)
# pair 152: \C=C \ -> \C=C\ (frequency 315)
# pair 153: C( Cl) -> C(Cl) (frequency 315)
# pair 154: (C) CC -> (C)CC (frequency 313)
# pair 155: N (CC -> N(CC (frequency 306)
# pair 156: C 4 -> C4 (frequency 299)
# pair 157: C1 ) -> C1) (frequency 296)
# pair 158: N ([H]) -> N([H]) (frequency 293)
# pair 159: [H] [C@] -> [H][C@] (frequency 291)
# pair 160: C1=CC=C C=C1) -> C1=CC=CC=C1) (frequency 288)
# pair 161: C1 =O) -> C1=O) (frequency 288)
# pair 162: N C1=N -> NC1=N (frequency 274)
# pair 163: [C@@]([H]) (O) -> [C@@]([H])(O) (frequency 273)
# pair 164: C(C) =O) -> C(C)=O) (frequency 273)
# pair 165: N=C 2 -> N=C2 (frequency 267)
# pair 166: (C) C) -> (C)C) (frequency 266)
# pair 167: B r -> Br (frequency 261)
# pair 168: [C@]1 2 -> [C@]12 (frequency 258)
# pair 169: C(=C 1) -> C(=C1) (frequency 256)
# pair 170: 3 ([H]) -> 3([H]) (frequency 255)
# pair 171: N =C1 -> N=C1 (frequency 254)
# pair 172: C( CC -> C(CC (frequency 253)
# pair 173: C [C@H](O) -> C[C@H](O) (frequency 253)
# pair 174: C(=O)N 1 -> C(=O)N1 (frequency 251)
# pair 175: C(=O) O -> C(=O)O (frequency 251)
# pair 176: [C@ H]3 -> [C@H]3 (frequency 247)
# pair 177: C(O) =C -> C(O)=C (frequency 246)
# pair 178: C(C) C) -> C(C)C) (frequency 246)
# pair 179: Br ) -> Br) (frequency 245)
# pair 180: C1=C 2 -> C1=C2 (frequency 241)
# pair 181: 4 ) -> 4) (frequency 239)
# pair 182: C1=C C2=C( -> C1=CC2=C( (frequency 238)
# pair 183: [C@] 2 -> [C@]2 (frequency 235)
# pair 184: [C@@]([H]) ( -> [C@@]([H])( (frequency 231)
# pair 185: C S -> CS (frequency 227)
# pair 186: [H][C@@]1 2CC -> [H][C@@]12CC (frequency 223)
# pair 187: C # -> C# (frequency 220)
# pair 188: (=O) =O) -> (=O)=O) (frequency 220)
# pair 189: [C@@H]( O -> [C@@H](O (frequency 216)
# pair 190: (O) =O</w> -> (O)=O</w> (frequency 215)
# pair 191: ([O-]) =O) -> ([O-])=O) (frequency 212)
# pair 192: N [C@@H]( -> N[C@@H]( (frequency 211)
# pair 193: (CC 1 -> (CC1 (frequency 210)
# pair 194: N CC -> NCC (frequency 209)
# pair 195: C1=CC=C C=C1 -> C1=CC=CC=C1 (frequency 209)
# pair 196: C(C) =C -> C(C)=C (frequency 208)
# pair 197: [C@@H](O) [C@H](O) -> [C@@H](O)[C@H](O) (frequency 206)
# pair 198: C( OC) -> C(OC) (frequency 198)
# pair 199: O[C@H]( CO) -> O[C@H](CO) (frequency 197)
# pair 200: I ) -> I) (frequency 197)
# pair 201: N 1) -> N1) (frequency 195)
# pair 202: C=C 3 -> C=C3 (frequency 195)
# pair 203: ( CO -> (CO (frequency 192)
# pair 204: P(O)(=O) O -> P(O)(=O)O (frequency 191)
# pair 205: CC CN -> CCCN (frequency 190)
# pair 206: [C@@ H]3 -> [C@@H]3 (frequency 187)
# pair 207: N (C) -> N(C) (frequency 185)
# pair 208: O 1) -> O1) (frequency 184)
# pair 209: CC1 =C( -> CC1=C( (frequency 183)
# pair 210: C2=CC=C C=C2 -> C2=CC=CC=C2 (frequency 180)
# pair 211: CC1=CC=C C=C1) -> CC1=CC=CC=C1) (frequency 178)
# pair 212: C2 ) -> C2) (frequency 176)
# pair 213: C(=O) CC -> C(=O)CC (frequency 175)
# pair 214: =C 2 -> =C2 (frequency 175)
# pair 215: =CC=C 1 -> =CC=C1 (frequency 174)
# pair 216: NC(=O) [C@@H]( -> NC(=O)[C@@H]( (frequency 173)
# pair 217: C(F)(F) F) -> C(F)(F)F) (frequency 170)
# pair 218: C=C C=C -> C=CC=C (frequency 169)
# pair 219: C [C@@H]( -> C[C@@H]( (frequency 168)
# pair 220: CC2 =CC=C -> CC2=CC=C (frequency 167)
# pair 221: C(=O)N CC -> C(=O)NCC (frequency 165)
# pair 222: [H][C@]1 2 -> [H][C@]12 (frequency 164)
# pair 223: C2=CC=C C=C2) -> C2=CC=CC=C2) (frequency 162)
# pair 224: C(N) =O) -> C(N)=O) (frequency 160)
# pair 225: C1=CC=C (O) -> C1=CC=C(O) (frequency 159)
# pair 226: (=O) =O</w> -> (=O)=O</w> (frequency 159)
# pair 227: ( NC(=O) -> (NC(=O) (frequency 159)
# pair 228: OCC OCC -> OCCOCC (frequency 158)
# pair 229: [C@]12 C</w> -> [C@]12C</w> (frequency 156)
# pair 230: C2 =O) -> C2=O) (frequency 156)
# pair 231: ( N -> (N (frequency 156)
# pair 232: C1=C (O) -> C1=C(O) (frequency 155)
# pair 233: C(=O)N ([H]) -> C(=O)N([H]) (frequency 153)
# pair 234: \ C( -> \C( (frequency 152)
# pair 235: [H][C@@]1 2 -> [H][C@@]12 (frequency 152)
# pair 236: CC O -> CCO (frequency 152)
# pair 237: C [C@@H](O) -> C[C@@H](O) (frequency 152)
# pair 238: C1=CC=C 2 -> C1=CC=C2 (frequency 150)
# pair 239: S 1) -> S1) (frequency 149)
# pair 240: CC 1</w> -> CC1</w> (frequency 149)
# pair 241: [C@@] 3([H]) -> [C@@]3([H]) (frequency 148)
# pair 242: [C@] 4 -> [C@]4 (frequency 146)
# pair 243: C2=CC=C C=C1 -> C2=CC=CC=C1 (frequency 146)
# pair 244: @ ] -> @] (frequency 146)
# pair 245: =C (O) -> =C(O) (frequency 146)
# pair 246: O [C@]([H]) -> O[C@]([H]) (frequency 145)
# pair 247: C( [O-]) -> C([O-]) (frequency 145)
# pair 248: N1 C(=O) -> N1C(=O) (frequency 143)
# pair 249: H] 4 -> H]4 (frequency 143)
# pair 250: N =N -> N=N (frequency 140)
# pair 251: C NC(=O) -> CNC(=O) (frequency 139)
# pair 252: [C@H]1 O</w> -> [C@H]1O</w> (frequency 138)
# pair 253: C2=CC=C ( -> C2=CC=C( (frequency 138)
# pair 254: +] . -> +]. (frequency 136)
# pair 255: CC1=CC=C ( -> CC1=CC=C( (frequency 135)
# pair 256: (O) ( -> (O)( (frequency 134)
# pair 257: S ) -> S) (frequency 133)
# pair 258: CC ) -> CC) (frequency 133)
# pair 259: C(N)=N ) -> C(N)=N) (frequency 133)
# pair 260: (CC1 =CC=C -> (CC1=CC=C (frequency 133)
# pair 261: CC(=O) N -> CC(=O)N (frequency 132)
# pair 262: C(F)(F) F</w> -> C(F)(F)F</w> (frequency 132)
# pair 263: =CC=C 1) -> =CC=C1) (frequency 132)
# pair 264: OC [C@H]1 -> OC[C@H]1 (frequency 131)
# pair 265: C [C@@H]1 -> C[C@@H]1 (frequency 131)
# pair 266: =C 2) -> =C2) (frequency 131)
# pair 267: C2=C1 C=C -> C2=C1C=C (frequency 130)
# pair 268: O . -> O. (frequency 129)
# pair 269: CC OCC -> CCOCC (frequency 129)
# pair 270: CC C(O)=O) -> CCC(O)=O) (frequency 129)
# pair 271: C3 =N -> C3=N (frequency 129)
# pair 272: [C@]2 ([H]) -> [C@]2([H]) (frequency 127)
# pair 273: S (O) -> S(O) (frequency 127)
# pair 274: O[C@H]( CO -> O[C@H](CO (frequency 127)
# pair 275: \C=C / -> \C=C/ (frequency 126)
# pair 276: [C@]1([H]) O</w> -> [C@]1([H])O</w> (frequency 125)
# pair 277: N C(=O)N -> NC(=O)N (frequency 125)
# pair 278: C O</w> -> CO</w> (frequency 125)
# pair 279: C1=CC=C (Cl) -> C1=CC=C(Cl) (frequency 124)
# pair 280: N S(=O)(=O) -> NS(=O)(=O) (frequency 123)
# pair 281: C=N 1</w> -> C=N1</w> (frequency 123)
# pair 282: C( O -> C(O (frequency 122)
# pair 283: (CC ) -> (CC) (frequency 122)
# pair 284: C(N) =O</w> -> C(N)=O</w> (frequency 120)
# pair 285: [C@@]1 (C)CC -> [C@@]1(C)CC (frequency 119)
# pair 286: N 3 -> N3 (frequency 118)
# pair 287: C(=O) [C@H]( -> C(=O)[C@H]( (frequency 118)
# pair 288: C 1</w> -> C1</w> (frequency 118)
# pair 289: ([O-]) =O</w> -> ([O-])=O</w> (frequency 118)
# pair 290: (CC 2 -> (CC2 (frequency 118)
# pair 291: [H] N([H]) -> [H]N([H]) (frequency 117)
# pair 292: CC (O)=O) -> CC(O)=O) (frequency 116)
# pair 293: =C 1) -> =C1) (frequency 116)
# pair 294: C3=C 2 -> C3=C2 (frequency 114)
# pair 295: CC1 =N -> CC1=N (frequency 113)
# pair 296: C# N) -> C#N) (frequency 113)
# pair 297: C [C@H]1 -> C[C@H]1 (frequency 113)
# pair 298: P(O) (O)=O</w> -> P(O)(O)=O</w> (frequency 112)
# pair 299: C1=C( C) -> C1=C(C) (frequency 112)
# pair 300: [C@H]( N) -> [C@H](N) (frequency 111)
# pair 301: N 2) -> N2) (frequency 111)
# pair 302: [ H -> [H (frequency 110)
# pair 303: C2=C 1</w> -> C2=C1</w> (frequency 110)
# pair 304: [C@@]1 (C) -> [C@@]1(C) (frequency 109)
# pair 305: CC(C) C) -> CC(C)C) (frequency 108)
# pair 306: =CC=C 1</w> -> =CC=C1</w> (frequency 108)
# pair 307: [C@@]2([H]) CC -> [C@@]2([H])CC (frequency 107)
# pair 308: O [C@@H]1 -> O[C@@H]1 (frequency 107)
# pair 309: CN (C) -> CN(C) (frequency 107)
# pair 310: CC(C) (C) -> CC(C)(C) (frequency 107)
# pair 311: [C@] 3([H]) -> [C@]3([H]) (frequency 106)
# pair 312: [ P -> [P (frequency 106)
# pair 313: O [C@@]([H])( -> O[C@@]([H])( (frequency 106)
# pair 314: O 2) -> O2) (frequency 105)
# pair 315: N=C N=C2 -> N=CN=C2 (frequency 105)
# pair 316: CCN(CC 1) -> CCN(CC1) (frequency 105)
# pair 317: C4 =C -> C4=C (frequency 105)
# pair 318: O 1</w> -> O1</w> (frequency 104)
# pair 319: C(=O) C=C -> C(=O)C=C (frequency 104)
# pair 320: [H ]</w> -> [H]</w> (frequency 103)
# pair 321: C=N C2=C1 -> C=NC2=C1 (frequency 103)
# pair 322: C=N 2) -> C=N2) (frequency 103)
# pair 323: C1 CCCC -> C1CCCC (frequency 102)
# pair 324: (C) (O) -> (C)(O) (frequency 102)
# pair 325: C l</w> -> Cl</w> (frequency 101)
# pair 326: ( CCCC -> (CCCC (frequency 101)
# pair 327: C2=C 1) -> C2=C1) (frequency 100)
# pair 328: C(=O)N1 CCC -> C(=O)N1CCC (frequency 100)
# pair 329: [C@@] 3 -> [C@@]3 (frequency 99)
# pair 330: CC 1) -> CC1) (frequency 99)
# pair 331: [N+] ([O-])=O) -> [N+]([O-])=O) (frequency 97)
# pair 332: [C@H](O) [C@H](O) -> [C@H](O)[C@H](O) (frequency 97)
# pair 333: N=C( N) -> N=C(N) (frequency 97)
# pair 334: C(C)(C) C) -> C(C)(C)C) (frequency 97)
# pair 335: O [C@H]1 -> O[C@H]1 (frequency 96)
# pair 336: C3 ) -> C3) (frequency 96)
# pair 337: [C@H]2 O) -> [C@H]2O) (frequency 95)
# pair 338: C=C C=C1 -> C=CC=C1 (frequency 95)
# pair 339: [C@H](O) [C@@H](O) -> [C@H](O)[C@@H](O) (frequency 94)
# pair 340: N1 C=C -> N1C=C (frequency 94)
# pair 341: CC1=C N -> CC1=CN (frequency 94)
# pair 342: [H][C@] (N) -> [H][C@](N) (frequency 93)
# pair 343: CN (CC -> CN(CC (frequency 93)
# pair 344: [C@@H]1 O</w> -> [C@@H]1O</w> (frequency 92)
# pair 345: CO C1=C( -> COC1=C( (frequency 92)
# pair 346: CC2 =C -> CC2=C (frequency 92)
# pair 347: C( Br) -> C(Br) (frequency 91)
# pair 348: [N+] ([O-])=O</w> -> [N+]([O-])=O</w> (frequency 90)
# pair 349: [H][C@]1 (O) -> [H][C@]1(O) (frequency 90)
# pair 350: S CC -> SCC (frequency 90)
# pair 351: N2 C=N -> N2C=N (frequency 90)
# pair 352: C1=CC=C(O) C=C1</w> -> C1=CC=C(O)C=C1</w> (frequency 90)
# pair 353: CO C(=O) -> COC(=O) (frequency 89)
# pair 354: C=N 1) -> C=N1) (frequency 89)
# pair 355: C(=C 2) -> C(=C2) (frequency 88)
# pair 356: CC 2) -> CC2) (frequency 87)
# pair 357: C1=C( F) -> C1=C(F) (frequency 87)
# pair 358: [H][C@@]1 (CC -> [H][C@@]1(CC (frequency 86)
# pair 359: [C@H]( O -> [C@H](O (frequency 86)
# pair 360: CC1=CC=C( C=C1) -> CC1=CC=C(C=C1) (frequency 86)
# pair 361: C(C) =C( -> C(C)=C( (frequency 86)
# pair 362: C(=N 1) -> C(=N1) (frequency 86)
# pair 363: [C@@]([H]) (O -> [C@@]([H])(O (frequency 85)
# pair 364: S (N) -> S(N) (frequency 85)
# pair 365: N1 CC -> N1CC (frequency 85)
# pair 366: CO P(O)(O)=O) -> COP(O)(O)=O) (frequency 85)
# pair 367: CO C1=CC( -> COC1=CC( (frequency 85)
# pair 368: C2 =O</w> -> C2=O</w> (frequency 85)
# pair 369: C1=C( Cl) -> C1=C(Cl) (frequency 85)
# pair 370: [C@@H]( CO) -> [C@@H](CO) (frequency 84)
# pair 371: S 2) -> S2) (frequency 84)
# pair 372: C=C1) C(O)=O</w> -> C=C1)C(O)=O</w> (frequency 84)
# pair 373: C1=C N -> C1=CN (frequency 84)
# pair 374: C(=O)N C1=O</w> -> C(=O)NC1=O</w> (frequency 84)
# pair 375: C(=O)N ( -> C(=O)N( (frequency 84)
# pair 376: =C( OC) -> =C(OC) (frequency 84)
# pair 377: S 1</w> -> S1</w> (frequency 82)
# pair 378: CCCC CC -> CCCCCC (frequency 81)
# pair 379: C2=CC=CC=C1 2) -> C2=CC=CC=C12) (frequency 81)
# pair 380: C2=C( C=C -> C2=C(C=C (frequency 81)
# pair 381: [C@@H]1 O) -> [C@@H]1O) (frequency 80)
# pair 382: [C@@H]1 CC -> [C@@H]1CC (frequency 80)
# pair 383: S (C) -> S(C) (frequency 80)
# pair 384: [C@@]2 1 -> [C@@]21 (frequency 79)
# pair 385: O[C@H](CO) [C@@H](O)[C@H](O) -> O[C@H](CO)[C@@H](O)[C@H](O) (frequency 79)
# pair 386: O[C@H]( [C@H](O) -> O[C@H]([C@H](O) (frequency 79)
# pair 387: CN 2 -> CN2 (frequency 79)
# pair 388: C1=C C(=C -> C1=CC(=C (frequency 79)
# pair 389: N C2=N -> NC2=N (frequency 78)
# pair 390: C( = -> C(= (frequency 78)
# pair 391: [N H -> [NH (frequency 77)
# pair 392: [C@@]1([H]) [C@@]2([H])CC -> [C@@]1([H])[C@@]2([H])CC (frequency 77)
# pair 393: S(O) (=O)=O) -> S(O)(=O)=O) (frequency 77)
# pair 394: =C( C) -> =C(C) (frequency 77)
# pair 395: ] . -> ]. (frequency 76)
# pair 396: [C@@ H]4 -> [C@@H]4 (frequency 76)
# pair 397: C(Cl) =C -> C(Cl)=C (frequency 76)
# pair 398: C(C) C</w> -> C(C)C</w> (frequency 76)
# pair 399: C(=N ) -> C(=N) (frequency 76)
# pair 400: C l -> Cl (frequency 76)
# pair 401: = O. -> =O. (frequency 76)
# pair 402: [C@@]([H])(O) [C@]([H])(O) -> [C@@]([H])(O)[C@]([H])(O) (frequency 75)
# pair 403: C1=CC=C( F) -> C1=CC=C(F) (frequency 75)
# pair 404: =N 1) -> =N1) (frequency 75)
# pair 405: CN ( -> CN( (frequency 74)
# pair 406: CCCN C(N)=N) -> CCCNC(N)=N) (frequency 74)
# pair 407: C=C (O) -> C=C(O) (frequency 74)
# pair 408: C1=CC2=C( C=C1) -> C1=CC2=C(C=C1) (frequency 74)
# pair 409: C([O-]) =O</w> -> C([O-])=O</w> (frequency 74)
# pair 410: C(=O)N 1</w> -> C(=O)N1</w> (frequency 74)
# pair 411: [C@@]([H]) (C) -> [C@@]([H])(C) (frequency 73)
# pair 412: O C</w> -> OC</w> (frequency 73)
# pair 413: CCCC N) -> CCCCN) (frequency 73)
# pair 414: (CC1=CC=C C=C1) -> (CC1=CC=CC=C1) (frequency 73)
# pair 415: [C@] (O)( -> [C@](O)( (frequency 72)
# pair 416: [C@@] 4 -> [C@@]4 (frequency 72)
# pair 417: CO C1=CC=C -> COC1=CC=C (frequency 72)
# pair 418: =N 2) -> =N2) (frequency 72)
# pair 419: [H] N( -> [H]N( (frequency 71)
# pair 420: [C@]12 C) -> [C@]12C) (frequency 71)
# pair 421: [C@]([H]) ( -> [C@]([H])( (frequency 71)
# pair 422: N=C 3 -> N=C3 (frequency 71)
# pair 423: N 1</w> -> N1</w> (frequency 71)
# pair 424: C2=CC=C( C=C2) -> C2=CC=C(C=C2) (frequency 71)
# pair 425: @] (O) -> @](O) (frequency 71)
# pair 426: [C@H]3 O) -> [C@H]3O) (frequency 70)
# pair 427: C=C (Cl) -> C=C(Cl) (frequency 70)
# pair 428: C2=C C( -> C2=CC( (frequency 70)
# pair 429: C( \ -> C(\ (frequency 70)
# pair 430: N (C)C) -> N(C)C) (frequency 69)
# pair 431: 4 =C -> 4=C (frequency 69)
# pair 432: 3 =CC=C -> 3=CC=C (frequency 69)
# pair 433: O [C@@H]( -> O[C@@H]( (frequency 68)
# pair 434: C(C) =O</w> -> C(C)=O</w> (frequency 68)
# pair 435: C(=O) [C@@H]( -> C(=O)[C@@H]( (frequency 68)
# pair 436: C(=O) OCC -> C(=O)OCC (frequency 68)
# pair 437: (O) C=C1) -> (O)C=C1) (frequency 68)
# pair 438: [H][C@@] (C) -> [H][C@@](C) (frequency 67)
# pair 439: [C@ H]4 -> [C@H]4 (frequency 67)
# pair 440: P(O)(=O)O P(O)(=O) -> P(O)(=O)OP(O)(=O) (frequency 67)
# pair 441: N C(C)=O) -> NC(C)=O) (frequency 67)
# pair 442: CC2=CC=C C=C2) -> CC2=CC=CC=C2) (frequency 67)
# pair 443: C=C C=C3) -> C=CC=C3) (frequency 67)
# pair 444: C(=O)N1CCC [C@H]1 -> C(=O)N1CCC[C@H]1 (frequency 67)
# pair 445: = [N+] -> =[N+] (frequency 67)
# pair 446: / C) -> /C) (frequency 67)
# pair 447: [C@]4 (C) -> [C@]4(C) (frequency 66)
# pair 448: [C@] 3 -> [C@]3 (frequency 66)
# pair 449: N=C 1</w> -> N=C1</w> (frequency 66)
# pair 450: CC1=CC=C C=C1</w> -> CC1=CC=CC=C1</w> (frequency 66)
# pair 451: =N 1</w> -> =N1</w> (frequency 66)
# pair 452: (N) =O) -> (N)=O) (frequency 66)
# pair 453: [C@@]3([H]) CC -> [C@@]3([H])CC (frequency 65)
# pair 454: O C( -> OC( (frequency 65)
# pair 455: N1C(=O) [C@H]2 -> N1C(=O)[C@H]2 (frequency 65)
# pair 456: CC OC(=O) -> CCOC(=O) (frequency 65)
# pair 457: C2=CC=CC=C1 2</w> -> C2=CC=CC=C12</w> (frequency 65)
# pair 458: C1=C C=N -> C1=CC=N (frequency 65)
# pair 459: C(C)(C) C</w> -> C(C)(C)C</w> (frequency 65)
# pair 460: C 5 -> C5 (frequency 65)
# pair 461: @](O) (=O) -> @](O)(=O) (frequency 65)
# pair 462: [C@H]1 O) -> [C@H]1O) (frequency 64)
# pair 463: [C@@]1(C) C[C@H](O) -> [C@@]1(C)C[C@H](O) (frequency 64)
# pair 464: O[C@]([H]) (CO) -> O[C@]([H])(CO) (frequency 64)
# pair 465: O) [C@]([H])(O) -> O)[C@]([H])(O) (frequency 64)
# pair 466: O CO -> OCO (frequency 64)
# pair 467: N C1=O) -> NC1=O) (frequency 64)
# pair 468: C[C@H]( N) -> C[C@H](N) (frequency 64)
# pair 469: CC [C@H]( -> CC[C@H]( (frequency 64)
# pair 470: C=CC=C 2</w> -> C=CC=C2</w> (frequency 64)
# pair 471: C=C( F) -> C=C(F) (frequency 64)
# pair 472: C4 =C( -> C4=C( (frequency 64)
# pair 473: [ S -> [S (frequency 63)
# pair 474: C [C@@H](C) -> C[C@@H](C) (frequency 63)
# pair 475: =CC=C 2 -> =CC=C2 (frequency 63)
# pair 476: (C) C</w> -> (C)C</w> (frequency 63)
# pair 477: [C@]([H])(O) [C@]1([H])O</w> -> [C@]([H])(O)[C@]1([H])O</w> (frequency 62)
# pair 478: [C@@H]( CC -> [C@@H](CC (frequency 62)
# pair 479: N=CN=C2 3) -> N=CN=C23) (frequency 62)
# pair 480: CC ( -> CC( (frequency 62)
# pair 481: C(= S) -> C(=S) (frequency 62)
# pair 482: [C@]([H]) (C) -> [C@]([H])(C) (frequency 61)
# pair 483: S(=O)(=O) N -> S(=O)(=O)N (frequency 61)
# pair 484: C1=N C2=C( -> C1=NC2=C( (frequency 61)
# pair 485: C1=CC=CC=C1) C1=CC=CC=C1</w> -> C1=CC=CC=C1)C1=CC=CC=C1</w> (frequency 61)
# pair 486: C# N</w> -> C#N</w> (frequency 61)
# pair 487: C \C=C/ -> C\C=C/ (frequency 61)
# pair 488: CCCCCCCC CCCCCCCC -> CCCCCCCCCCCCCCCC (frequency 60)
# pair 489: C4 =CC=C -> C4=CC=C (frequency 60)
# pair 490: C(C) =C1 -> C(C)=C1 (frequency 60)
# pair 491: C( NC(=O) -> C(NC(=O) (frequency 60)
# pair 492: =C( F) -> =C(F) (frequency 60)
# pair 493: =C ) -> =C) (frequency 60)
# pair 494: 3 ]. -> 3]. (frequency 60)
# pair 495: + 3]. -> +3]. (frequency 60)
# pair 496: [N+] (C) -> [N+](C) (frequency 59)
# pair 497: CCCC 1 -> CCCC1 (frequency 59)
# pair 498: CC (O) -> CC(O) (frequency 59)
# pair 499: C1=CC( Cl) -> C1=CC(Cl) (frequency 59)
# pair 500: C(O)=C (O) -> C(O)=C(O) (frequency 59)
# pair 501: C(=O)C=C [C@]12C</w> -> C(=O)C=C[C@]12C</w> (frequency 59)
# pair 502: + +]. -> ++]. (frequency 59)
# pair 503: [C@@]1([H]) O</w> -> [C@@]1([H])O</w> (frequency 58)
# pair 504: O =C1 -> O=C1 (frequency 58)
# pair 505: N=C( N -> N=C(N (frequency 58)
# pair 506: N=C 1) -> N=C1) (frequency 58)
# pair 507: C=C2 3) -> C=C23) (frequency 58)
# pair 508: C3=CC=C C=C3) -> C3=CC=CC=C3) (frequency 58)
# pair 509: C2=C C(=O)C=C[C@]12C</w> -> C2=CC(=O)C=C[C@]12C</w> (frequency 58)
# pair 510: C(O)=O) C(O)=O</w> -> C(O)=O)C(O)=O</w> (frequency 58)
# pair 511: C( OCC -> C(OCC (frequency 58)
# pair 512: C =O</w> -> C=O</w> (frequency 58)
# pair 513: [C@]4 ([H]) -> [C@]4([H]) (frequency 57)
# pair 514: [C@H]1 CC -> [C@H]1CC (frequency 57)
# pair 515: NC1=N C2=C( -> NC1=NC2=C( (frequency 57)
# pair 516: C N) -> CN) (frequency 57)
# pair 517: C =O) -> C=O) (frequency 57)
# pair 518: =CC=C 2) -> =CC=C2) (frequency 57)
# pair 519: O[C@H](CO) [C@@H](O) -> O[C@H](CO)[C@@H](O) (frequency 56)
# pair 520: O C1=C( -> OC1=C( (frequency 56)
# pair 521: C=C 4 -> C=C4 (frequency 56)
# pair 522: =C( Cl) -> =C(Cl) (frequency 56)
# pair 523: C=C( /C) -> C=C(/C) (frequency 55)
# pair 524: C3=CC=C ( -> C3=CC=C( (frequency 55)
# pair 525: C [C@@] -> C[C@@] (frequency 55)
# pair 526: =C \ -> =C\ (frequency 55)
# pair 527: 5 ) -> 5) (frequency 55)
# pair 528: 2 =CC=C -> 2=CC=C (frequency 55)
# pair 529: (C S -> (CS (frequency 55)
# pair 530: [H][C@@]1 (O) -> [H][C@@]1(O) (frequency 54)
# pair 531: O C1=CC=C(C=C1) -> OC1=CC=C(C=C1) (frequency 54)
# pair 532: N2C=N C3=C( -> N2C=NC3=C( (frequency 54)
# pair 533: CC [C@@]21 -> CC[C@@]21 (frequency 54)
# pair 534: C(=O)N 2 -> C(=O)N2 (frequency 54)
# pair 535: =C( \ -> =C(\ (frequency 54)
# pair 536: -] . -> -]. (frequency 54)
# pair 537: (CC2 =CC=C -> (CC2=CC=C (frequency 54)
# pair 538: \ C(C)=C -> \C(C)=C (frequency 53)
# pair 539: NC(=O) CC -> NC(=O)CC (frequency 53)
# pair 540: N=C N2 -> N=CN2 (frequency 53)
# pair 541: N1 C=N -> N1C=N (frequency 53)
# pair 542: CN1 C(=O) -> CN1C(=O) (frequency 53)
# pair 543: CCN(CC ) -> CCN(CC) (frequency 53)
# pair 544: C3=CC=C C=C3 -> C3=CC=CC=C3 (frequency 53)
# pair 545: C1=N C=C -> C1=NC=C (frequency 53)
# pair 546: [C@@]([H]) (CO) -> [C@@]([H])(CO) (frequency 52)
# pair 547: CC C(CC -> CCC(CC (frequency 52)
# pair 548: C2=C 3 -> C2=C3 (frequency 52)
# pair 549: C1=CC=C(Cl) C=C1</w> -> C1=CC=C(Cl)C=C1</w> (frequency 52)
# pair 550: C(=O) C( -> C(=O)C( (frequency 52)
# pair 551: P ([O-]) -> P([O-]) (frequency 51)
# pair 552: OCCOCC OCCOCC -> OCCOCCOCCOCC (frequency 51)
# pair 553: C(=O)N [C@H]( -> C(=O)N[C@H]( (frequency 51)
# pair 554: (CC (C)C) -> (CC(C)C) (frequency 51)
# pair 555: a +]. -> a+]. (frequency 50)
# pair 556: [N a+]. -> [Na+]. (frequency 50)
# pair 557: [H][C@]1 (CC -> [H][C@]1(CC (frequency 50)
# pair 558: S(N) (=O)=O</w> -> S(N)(=O)=O</w> (frequency 50)
# pair 559: CC N1 -> CCN1 (frequency 50)
# pair 560: C=C ) -> C=C) (frequency 50)
# pair 561: C(N) = -> C(N)= (frequency 50)
# pair 562: (C # -> (C# (frequency 50)
# pair 563: [H][C@]1 (CO) -> [H][C@]1(CO) (frequency 49)
# pair 564: [C@] (C) -> [C@](C) (frequency 49)
# pair 565: [C@@H]2 O) -> [C@@H]2O) (frequency 49)
# pair 566: S(C) (=O)=O) -> S(C)(=O)=O) (frequency 49)
# pair 567: NC(=O)[C@H]( CC -> NC(=O)[C@H](CC (frequency 49)
# pair 568: C4=C 3 -> C4=C3 (frequency 49)
# pair 569: C1=N N -> C1=NN (frequency 49)
# pair 570: C(=N 2) -> C(=N2) (frequency 49)
# pair 571: =C 4 -> =C4 (frequency 49)
# pair 572: CC 3) -> CC3) (frequency 48)
# pair 573: C1=CC=C C(=C1) -> C1=CC=CC(=C1) (frequency 48)
# pair 574: C1=C2 C=C -> C1=C2C=C (frequency 48)
# pair 575: C(O)=C 2 -> C(O)=C2 (frequency 48)
# pair 576: C(=O) C2=C( -> C(=O)C2=C( (frequency 48)
# pair 577: C C</w> -> CC</w> (frequency 48)
# pair 578: (O) C=C2) -> (O)C=C2) (frequency 48)
# pair 579: [C@@]2([H]) [C@]3([H]) -> [C@@]2([H])[C@]3([H]) (frequency 47)
# pair 580: [C@@]1(C)CC [C@@]1([H])[C@@]2([H])CC -> [C@@]1(C)CC[C@@]1([H])[C@@]2([H])CC (frequency 47)
# pair 581: S(O) (=O)=O</w> -> S(O)(=O)=O</w> (frequency 47)
# pair 582: N) N=CN=C23) -> N)N=CN=C23) (frequency 47)
# pair 583: N C(=N) -> NC(=N) (frequency 47)
# pair 584: C=C( C=C2) -> C=C(C=C2) (frequency 47)
# pair 585: C=C( C=C1) -> C=C(C=C1) (frequency 47)
# pair 586: C1=C S -> C1=CS (frequency 47)
# pair 587: C(O) =C1 -> C(O)=C1 (frequency 47)
# pair 588: (F) (F) -> (F)(F) (frequency 47)
# pair 589: (=O) N -> (=O)N (frequency 47)
# pair 590: [C@]([H]) (O -> [C@]([H])(O (frequency 46)
# pair 591: [ A -> [A (frequency 46)
# pair 592: N=C N( -> N=CN( (frequency 46)
# pair 593: I) C( -> I)C( (frequency 46)
# pair 594: CCCC C2) -> CCCCC2) (frequency 46)
# pair 595: CCC 4=C -> CCC4=C (frequency 46)
# pair 596: C3 =O) -> C3=O) (frequency 46)
# pair 597: (CC (O)=O) -> (CC(O)=O) (frequency 46)
# pair 598: [H][C@@] (N) -> [H][C@@](N) (frequency 45)
# pair 599: N=C 2) -> N=C2) (frequency 45)
# pair 600: F e -> Fe (frequency 45)
# pair 601: CC1=CC=C (O)C=C1) -> CC1=CC=C(O)C=C1) (frequency 45)
# pair 602: C=C2) C=C1</w> -> C=C2)C=C1</w> (frequency 45)
# pair 603: C=C (C) -> C=C(C) (frequency 45)
# pair 604: C1=CC=C( O -> C1=CC=C(O (frequency 45)
# pair 605: [N -] -> [N-] (frequency 44)
# pair 606: [H][C@]1 (CO -> [H][C@]1(CO (frequency 44)
# pair 607: [H][C@@] (O) -> [H][C@@](O) (frequency 44)
# pair 608: [C@@]1 (O) -> [C@@]1(O) (frequency 44)
# pair 609: [ Fe -> [Fe (frequency 44)
# pair 610: N=C1 2) -> N=C12) (frequency 44)
# pair 611: CO C1=CC=C(C=C1) -> COC1=CC=C(C=C1) (frequency 44)
# pair 612: C2=C( N) -> C2=C(N) (frequency 44)
# pair 613: C1=CC=C( C=C1 -> C1=CC=C(C=C1 (frequency 44)
# pair 614: C(OC) =C1 -> C(OC)=C1 (frequency 44)
# pair 615: C(O) =C( -> C(O)=C( (frequency 44)
# pair 616: C(=N / -> C(=N/ (frequency 44)
# pair 617: C( CO) -> C(CO) (frequency 44)
# pair 618: ( OC(=O) -> (OC(=O) (frequency 44)
# pair 619: [P @](O)(=O) -> [P@](O)(=O) (frequency 43)
# pair 620: [N+] 1 -> [N+]1 (frequency 43)
# pair 621: [H] \C( -> [H]\C( (frequency 43)
# pair 622: [C@@H](O) [C@H]1O</w> -> [C@@H](O)[C@H]1O</w> (frequency 43)
# pair 623: O[C@@]([H])( N2C=NC3=C( -> O[C@@]([H])(N2C=NC3=C( (frequency 43)
# pair 624: O) C(O)=O</w> -> O)C(O)=O</w> (frequency 43)
# pair 625: O P(O)(O)=O) -> OP(O)(O)=O) (frequency 43)
# pair 626: NCC (O) -> NCC(O) (frequency 43)
# pair 627: N1C(=O)[C@H]2 NC(=O) -> N1C(=O)[C@H]2NC(=O) (frequency 43)
# pair 628: C=C 2</w> -> C=C2</w> (frequency 43)
# pair 629: C2=C C3=C( -> C2=CC3=C( (frequency 43)
# pair 630: C1=CC=C( N -> C1=CC=C(N (frequency 43)
# pair 631: C(=C 3) -> C(=C3) (frequency 43)
# pair 632: =C 3 -> =C3 (frequency 43)
# pair 633: = C</w> -> =C</w> (frequency 43)
# pair 634: [C@](O)( C(=O) -> [C@](O)(C(=O) (frequency 42)
# pair 635: [C@] (O) -> [C@](O) (frequency 42)
# pair 636: [C@] (C)(O) -> [C@](C)(O) (frequency 42)
# pair 637: [C@@]1(C)CC [C@]1([H]) -> [C@@]1(C)CC[C@]1([H]) (frequency 42)
# pair 638: C[C@H]( C) -> C[C@H](C) (frequency 42)
# pair 639: C=C / -> C=C/ (frequency 42)
# pair 640: C1=CC=CC=C1) C(O)=O</w> -> C1=CC=CC=C1)C(O)=O</w> (frequency 42)
# pair 641: C(Cl) =C1</w> -> C(Cl)=C1</w> (frequency 42)
# pair 642: C( =C1 -> C(=C1 (frequency 42)
# pair 643: [C@]1 (O) -> [C@]1(O) (frequency 41)
# pair 644: [C@H]( CC -> [C@H](CC (frequency 41)
# pair 645: [C@@H]( CO -> [C@@H](CO (frequency 41)
# pair 646: NC(=O) O -> NC(=O)O (frequency 41)
# pair 647: N=C1 2</w> -> N=C12</w> (frequency 41)
# pair 648: N1 CCCC -> N1CCCC (frequency 41)
# pair 649: CCCC 2) -> CCCC2) (frequency 41)
# pair 650: C3=CC=C C=C23) -> C3=CC=CC=C23) (frequency 41)
# pair 651: C2=CC=C (F) -> C2=CC=C(F) (frequency 41)
# pair 652: C(O) =C1</w> -> C(O)=C1</w> (frequency 41)
# pair 653: (C =N1) -> (C=N1) (frequency 41)
# pair 654: [C@]([H]) (C -> [C@]([H])(C (frequency 40)
# pair 655: [C@@]4 ([H]) -> [C@@]4([H]) (frequency 40)
# pair 656: P([O-]) (=O) -> P([O-])(=O) (frequency 40)
# pair 657: P(O)(=O)O P(O)(O)=O) -> P(O)(=O)OP(O)(O)=O) (frequency 40)
# pair 658: O[C@H]( C) -> O[C@H](C) (frequency 40)
# pair 659: OC[C@H]1 O[C@H]([C@H](O) -> OC[C@H]1O[C@H]([C@H](O) (frequency 40)
# pair 660: OC [C@@H](O) -> OC[C@@H](O) (frequency 40)
# pair 661: O [C@@H]2 -> O[C@@H]2 (frequency 40)
# pair 662: O =C( -> O=C( (frequency 40)
# pair 663: C=C C=C2) -> C=CC=C2) (frequency 40)
# pair 664: C1=CC( =CC=C1) -> C1=CC(=CC=C1) (frequency 40)
# pair 665: C(=O)CC [C@]12C</w> -> C(=O)CC[C@]12C</w> (frequency 40)
# pair 666: 3 CC -> 3CC (frequency 40)
# pair 667: / [H]) -> /[H]) (frequency 40)
# pair 668: +] ) -> +]) (frequency 40)
# pair 669: [C@]1 (C) -> [C@]1(C) (frequency 39)
# pair 670: [C@@H]1 O[C@H](CO -> [C@@H]1O[C@H](CO (frequency 39)
# pair 671: [C@@H]( N) -> [C@@H](N) (frequency 39)
# pair 672: OC[C@H]1 O[C@H]( -> OC[C@H]1O[C@H]( (frequency 39)
# pair 673: CCCCCCCC CCCC -> CCCCCCCCCCCC (frequency 39)
# pair 674: CC1=C C( -> CC1=CC( (frequency 39)
# pair 675: C=C1 2) -> C=C12) (frequency 39)
# pair 676: C=C C=C2 -> C=CC=C2 (frequency 39)
# pair 677: C1=C( C=C -> C1=C(C=C (frequency 39)
# pair 678: C(N)=N 1) -> C(N)=N1) (frequency 39)
# pair 679: C( CN -> C(CN (frequency 39)
# pair 680: C [C@H]2 -> C[C@H]2 (frequency 39)
# pair 681: (C) (C) -> (C)(C) (frequency 39)
# pair 682: \ N=C( -> \N=C( (frequency 38)
# pair 683: \ C=C(/C) -> \C=C(/C) (frequency 38)
# pair 684: [P @ -> [P@ (frequency 38)
# pair 685: [H][C@]12 S -> [H][C@]12S (frequency 38)
# pair 686: [H][C@] (C) -> [H][C@](C) (frequency 38)
# pair 687: OC(=O) CC -> OC(=O)CC (frequency 38)
# pair 688: NC(=O)[C@H]( CO) -> NC(=O)[C@H](CO) (frequency 38)
# pair 689: N1 C=NC2=C1 -> N1C=NC2=C1 (frequency 38)
# pair 690: CO [C@H]1 -> CO[C@H]1 (frequency 38)
# pair 691: CCOCC 1) -> CCOCC1) (frequency 38)
# pair 692: C2=CC=C (Cl) -> C2=CC=C(Cl) (frequency 38)
# pair 693: C2=C1 C=CC=C2</w> -> C2=C1C=CC=C2</w> (frequency 38)
# pair 694: C1=C(O) C=C -> C1=C(O)C=C (frequency 38)
# pair 695: C 2</w> -> C2</w> (frequency 38)
# pair 696: =CC=C 3) -> =CC=C3) (frequency 38)
# pair 697: (CC1 =C -> (CC1=C (frequency 38)
# pair 698: \ C(=C -> \C(=C (frequency 37)
# pair 699: [H][C@]12 SCC -> [H][C@]12SCC (frequency 37)
# pair 700: [H][C@]1 ( -> [H][C@]1( (frequency 37)
# pair 701: [H][C@] (O) -> [H][C@](O) (frequency 37)
# pair 702: [C@H](N) C(O)=O</w> -> [C@H](N)C(O)=O</w> (frequency 37)
# pair 703: [C@@]([H])(O) [C@]1([H])O</w> -> [C@@]([H])(O)[C@]1([H])O</w> (frequency 37)
# pair 704: [C@@] (O) -> [C@@](O) (frequency 37)
# pair 705: OC [C@H]2 -> OC[C@H]2 (frequency 37)
# pair 706: N[C@@H]( CC -> N[C@@H](CC (frequency 37)
# pair 707: CN1 CCN(CC1) -> CN1CCN(CC1) (frequency 37)
# pair 708: CCOCC 1</w> -> CCOCC1</w> (frequency 37)
# pair 709: CC (O)=O</w> -> CC(O)=O</w> (frequency 37)
# pair 710: C2=C (O) -> C2=C(O) (frequency 37)
# pair 711: C1=CC=C(F) C=C1</w> -> C1=CC=C(F)C=C1</w> (frequency 37)
# pair 712: C1=CC=C( OCC -> C1=CC=C(OCC (frequency 37)
# pair 713: C1 (CC -> C1(CC (frequency 37)
# pair 714: C(=O)O C</w> -> C(=O)OC</w> (frequency 37)
# pair 715: C(=O)N (C) -> C(=O)N(C) (frequency 37)
# pair 716: \C=C \C=C -> \C=C\C=C (frequency 36)
# pair 717: [C@@]2 (C) -> [C@@]2(C) (frequency 36)
# pair 718: NC(=O)[C@H]( C) -> NC(=O)[C@H](C) (frequency 36)
# pair 719: N=C( C) -> N=C(C) (frequency 36)
# pair 720: N=C N -> N=CN (frequency 36)
# pair 721: N (C -> N(C (frequency 36)
# pair 722: CN1 C=C -> CN1C=C (frequency 36)
# pair 723: CCN (C)CC -> CCN(C)CC (frequency 36)
# pair 724: CC1 (C) -> CC1(C) (frequency 36)
# pair 725: C2=C1C=C C=C2) -> C2=C1C=CC=C2) (frequency 36)
# pair 726: C1=CC=C(O) C=C1) -> C1=CC=C(O)C=C1) (frequency 36)
# pair 727: C(OC) =C(OC) -> C(OC)=C(OC) (frequency 36)
# pair 728: C(O) =N -> C(O)=N (frequency 36)
# pair 729: C(F) =C -> C(F)=C (frequency 36)
# pair 730: 2) C=C1</w> -> 2)C=C1</w> (frequency 36)
# pair 731: [C@@]1 2 -> [C@@]12 (frequency 35)
# pair 732: [C@@]([H]) (CC -> [C@@]([H])(CC (frequency 35)
# pair 733: O[C@]([H]) (O -> O[C@]([H])(O (frequency 35)
# pair 734: O[C@@]([H])(N2C=NC3=C( N)N=CN=C23) -> O[C@@]([H])(N2C=NC3=C(N)N=CN=C23) (frequency 35)
# pair 735: CCN ( -> CCN( (frequency 35)
# pair 736: CC [C@]12C</w> -> CC[C@]12C</w> (frequency 35)
# pair 737: C3=CC=C( C=C3) -> C3=CC=C(C=C3) (frequency 35)
# pair 738: C2=N C=N1</w> -> C2=NC=N1</w> (frequency 35)
# pair 739: C2=C C(=O)CC[C@]12C</w> -> C2=CC(=O)CC[C@]12C</w> (frequency 35)
# pair 740: C1=C2 N=CN( -> C1=C2N=CN( (frequency 35)
# pair 741: C(=O)N (CC -> C(=O)N(CC (frequency 35)
# pair 742: C(=O) OC -> C(=O)OC (frequency 35)
# pair 743: C( [H]) -> C([H]) (frequency 35)
# pair 744: B (O) -> B(O) (frequency 35)
# pair 745: =C( N) -> =C(N) (frequency 35)
# pair 746: [H][C@]1 (C) -> [H][C@]1(C) (frequency 34)
# pair 747: [H] N1 -> [H]N1 (frequency 34)
# pair 748: [ 1 -> [1 (frequency 34)
# pair 749: S(N) (=O)=O) -> S(N)(=O)=O) (frequency 34)
# pair 750: CC[C@@]21 [H]</w> -> CC[C@@]21[H]</w> (frequency 34)
# pair 751: CC(C) C[C@H]( -> CC(C)C[C@H]( (frequency 34)
# pair 752: C=C( O -> C=C(O (frequency 34)
# pair 753: C=C 4) -> C=C4) (frequency 34)
# pair 754: C1=CC2=C( N -> C1=CC2=C(N (frequency 34)
# pair 755: C1=C( N -> C1=C(N (frequency 34)
# pair 756: C(N)= N</w> -> C(N)=N</w> (frequency 34)
# pair 757: C(C)(C) [C@@H]( -> C(C)(C)[C@@H]( (frequency 34)
# pair 758: C(=O)N [C@H]1 -> C(=O)N[C@H]1 (frequency 34)
# pair 759: B r</w> -> Br</w> (frequency 34)
# pair 760: 2 =C -> 2=C (frequency 34)
# pair 761: [H][C@@]1 (C -> [H][C@@]1(C (frequency 33)
# pair 762: [C@H]( CO) -> [C@H](CO) (frequency 33)
# pair 763: [C@@]1(C)C[C@H](O) [C@@]1 -> [C@@]1(C)C[C@H](O)[C@@]1 (frequency 33)
# pair 764: [C@@H](O P(O)(O)=O) -> [C@@H](OP(O)(O)=O) (frequency 33)
# pair 765: [C@@H](C) O) -> [C@@H](C)O) (frequency 33)
# pair 766: O [C@@H](O -> O[C@@H](O (frequency 33)
# pair 767: O 3) -> O3) (frequency 33)
# pair 768: N( C(=O) -> N(C(=O) (frequency 33)
# pair 769: CC [C@]4(C) -> CC[C@]4(C) (frequency 33)
# pair 770: C2=N 1</w> -> C2=N1</w> (frequency 33)
# pair 771: C2=C( C) -> C2=C(C) (frequency 33)
# pair 772: C2=C C(Cl) -> C2=CC(Cl) (frequency 33)
# pair 773: C1CCCC C1) -> C1CCCCC1) (frequency 33)
# pair 774: C1=CC( =CC=C1 -> C1=CC(=CC=C1 (frequency 33)
# pair 775: C1=C C(=N -> C1=CC(=N (frequency 33)
# pair 776: C(O)=O) C(=O) -> C(O)=O)C(=O) (frequency 33)
# pair 777: C(O) ( -> C(O)( (frequency 33)
# pair 778: C(=O)N([H]) [C@@H]( -> C(=O)N([H])[C@@H]( (frequency 33)
# pair 779: [O - -> [O- (frequency 32)
# pair 780: [H][C@@]12 C -> [H][C@@]12C (frequency 32)
# pair 781: [ 2 -> [2 (frequency 32)
# pair 782: F C(F)(F) -> FC(F)(F) (frequency 32)
# pair 783: CO C1=C -> COC1=C (frequency 32)
# pair 784: CN (C -> CN(C (frequency 32)
# pair 785: CC(=O) N[C@@H]( -> CC(=O)N[C@@H]( (frequency 32)
# pair 786: C=C( OC) -> C=C(OC) (frequency 32)
# pair 787: C1=CC=C2 N -> C1=CC=C2N (frequency 32)
# pair 788: C1=C2N=CN( [C@@H]3 -> C1=C2N=CN([C@@H]3 (frequency 32)
# pair 789: C(C) =N -> C(C)=N (frequency 32)
# pair 790: C(=O)N[C@@H]( CCC(O)=O) -> C(=O)N[C@@H](CCC(O)=O) (frequency 32)
# pair 791: C(=O)N( C=C1) -> C(=O)N(C=C1) (frequency 32)
# pair 792: C(=O)N C1=O) -> C(=O)NC1=O) (frequency 32)
# pair 793: C(=O)N 1) -> C(=O)N1) (frequency 32)
# pair 794: 4 =CC=C -> 4=CC=C (frequency 32)
# pair 795: / C=C/ -> /C=C/ (frequency 32)
# pair 796: ( C(O)=O) -> (C(O)=O) (frequency 32)
# pair 797: S C[C@H]( -> SC[C@H]( (frequency 31)
# pair 798: N=C N=C3 -> N=CN=C3 (frequency 31)
# pair 799: N2 C=C -> N2C=C (frequency 31)
# pair 800: H] ) -> H]) (frequency 31)
# pair 801: C[C@H]( F) -> C[C@H](F) (frequency 31)
# pair 802: CN (C)CC -> CN(C)CC (frequency 31)
# pair 803: CC [C@H](C) -> CC[C@H](C) (frequency 31)
# pair 804: C=C1 2</w> -> C=C12</w> (frequency 31)
# pair 805: C=C( Br) -> C=C(Br) (frequency 31)
# pair 806: C=C C=C1</w> -> C=CC=C1</w> (frequency 31)
# pair 807: C2=C( F) -> C2=C(F) (frequency 31)
# pair 808: C1CCCC C1</w> -> C1CCCCC1</w> (frequency 31)
# pair 809: C1=N C( -> C1=NC( (frequency 31)
# pair 810: C1=CC=C( O1) -> C1=CC=C(O1) (frequency 31)
# pair 811: C([O-]) =O. -> C([O-])=O. (frequency 31)
# pair 812: C(=O) OC) -> C(=O)OC) (frequency 31)
# pair 813: C(=O) C=C3 -> C(=O)C=C3 (frequency 31)
# pair 814: =C( /[H]) -> =C(/[H]) (frequency 31)
# pair 815: 3 =C -> 3=C (frequency 31)
# pair 816: ( OC) -> (OC) (frequency 31)
# pair 817: [C@]2 (C) -> [C@]2(C) (frequency 30)
# pair 818: [C@@]1 1 -> [C@@]11 (frequency 30)
# pair 819: [C@@] (C) -> [C@@](C) (frequency 30)
# pair 820: OCC ) -> OCC) (frequency 30)
# pair 821: O C1=C -> OC1=C (frequency 30)
# pair 822: O C(CC -> OC(CC (frequency 30)
# pair 823: NC(=O) C1=C -> NC(=O)C1=C (frequency 30)
# pair 824: NC(=O) C -> NC(=O)C (frequency 30)
# pair 825: N CCCC -> NCCCC (frequency 30)
# pair 826: COC1=C( OC) -> COC1=C(OC) (frequency 30)
# pair 827: CO P(O)(O)=O</w> -> COP(O)(O)=O</w> (frequency 30)
# pair 828: CN 2CC -> CN2CC (frequency 30)
# pair 829: C2=CC=C(F) C=C2) -> C2=CC=C(F)C=C2) (frequency 30)
# pair 830: C2=C(C=C C=C2) -> C2=C(C=CC=C2) (frequency 30)
# pair 831: C2=C( Cl) -> C2=C(Cl) (frequency 30)
# pair 832: C(=O)N[C@@H]( CC -> C(=O)N[C@@H](CC (frequency 30)
# pair 833: C( I) -> C(I) (frequency 30)
# pair 834: C( C(O)=O) -> C(C(O)=O) (frequency 30)
# pair 835: =C 3) -> =C3) (frequency 30)
# pair 836: ] (O) -> ](O) (frequency 29)
# pair 837: [NH 2 -> [NH2 (frequency 29)
# pair 838: [H][C@@]1(CC [C@@]2([H])[C@]3([H]) -> [H][C@@]1(CC[C@@]2([H])[C@]3([H]) (frequency 29)
# pair 839: [C@]([H]) (N) -> [C@]([H])(N) (frequency 29)
# pair 840: [C@@H](O) [C@H](C) -> [C@@H](O)[C@H](C) (frequency 29)
# pair 841: S(C) (=O)=O</w> -> S(C)(=O)=O</w> (frequency 29)
# pair 842: O[C@H](CO P(O)(O)=O) -> O[C@H](COP(O)(O)=O) (frequency 29)
# pair 843: N1 CCN(CC1) -> N1CCN(CC1) (frequency 29)
# pair 844: N([H]) [H]) -> N([H])[H]) (frequency 29)
# pair 845: N(CC (O)=O) -> N(CC(O)=O) (frequency 29)
# pair 846: N C1=O</w> -> NC1=O</w> (frequency 29)
# pair 847: CS ) -> CS) (frequency 29)
# pair 848: CO [C@@H]1 -> CO[C@@H]1 (frequency 29)
# pair 849: CC NC(=O) -> CCNC(=O) (frequency 29)
# pair 850: C=N \ -> C=N\ (frequency 29)
# pair 851: C=N 3) -> C=N3) (frequency 29)
# pair 852: C=C1) C(=O)N -> C=C1)C(=O)N (frequency 29)
# pair 853: C=C1 Cl</w> -> C=C1Cl</w> (frequency 29)
# pair 854: C=C( C=C1 -> C=C(C=C1 (frequency 29)
# pair 855: C3 =C1 -> C3=C1 (frequency 29)
# pair 856: C1=CC=C(C=C1) S(=O)(=O) -> C1=CC=C(C=C1)S(=O)(=O) (frequency 29)
# pair 857: C(F) =C1 -> C(F)=C1 (frequency 29)
# pair 858: C(=O)N[C@@H]( CCCCN) -> C(=O)N[C@@H](CCCCN) (frequency 29)
# pair 859: C(=O)N1CCC [C@@]1([H]) -> C(=O)N1CCC[C@@]1([H]) (frequency 29)
# pair 860: C S(=O)(=O) -> CS(=O)(=O) (frequency 29)
# pair 861: (O) CO) -> (O)CO) (frequency 29)
# pair 862: (CC ([O-])=O) -> (CC([O-])=O) (frequency 29)
# pair 863: \C(C)=C \ -> \C(C)=C\ (frequency 28)
# pair 864: [H][C@@]12CC [C@H](O) -> [H][C@@]12CC[C@H](O) (frequency 28)
# pair 865: [C@H]( NC(=O) -> [C@H](NC(=O) (frequency 28)
# pair 866: [C@@H](O)[C@H](O) [C@@H](O) -> [C@@H](O)[C@H](O)[C@@H](O) (frequency 28)
# pair 867: [C@@H](O) [C@@H](O) -> [C@@H](O)[C@@H](O) (frequency 28)
# pair 868: S C) -> SC) (frequency 28)
# pair 869: NC(=O)[C@@H]( N) -> NC(=O)[C@@H](N) (frequency 28)
# pair 870: H] 5 -> H]5 (frequency 28)
# pair 871: CCCC C3) -> CCCCC3) (frequency 28)
# pair 872: CCCC ) -> CCCC) (frequency 28)
# pair 873: CC1=CN C2=CC=CC=C12) -> CC1=CNC2=CC=CC=C12) (frequency 28)
# pair 874: CC CN1 -> CCCN1 (frequency 28)
# pair 875: C3=C 2) -> C3=C2) (frequency 28)
# pair 876: C1=CC=C(C=C1) C(=O)N -> C1=CC=C(C=C1)C(=O)N (frequency 28)
# pair 877: C1=CC( OC) -> C1=CC(OC) (frequency 28)
# pair 878: C1 CC1</w> -> C1CC1</w> (frequency 28)
# pair 879: C([O-]) =O) -> C([O-])=O) (frequency 28)
# pair 880: C(=O) C(=C -> C(=O)C(=C (frequency 28)
# pair 881: C(=O) C -> C(=O)C (frequency 28)
# pair 882: C [C@]1 -> C[C@]1 (frequency 28)
# pair 883: =C(\ [H]) -> =C(\[H]) (frequency 28)
# pair 884: ] ) -> ]) (frequency 27)
# pair 885: [H][C@]12S C(C)(C)[C@@H]( -> [H][C@]12SC(C)(C)[C@@H]( (frequency 27)
# pair 886: [H]N([H]) C1=N -> [H]N([H])C1=N (frequency 27)
# pair 887: [C@] 5 -> [C@]5 (frequency 27)
# pair 888: [C@H]3O) C2=NC=N1</w> -> [C@H]3O)C2=NC=N1</w> (frequency 27)
# pair 889: [C@@]1(C)C[C@H](O)[C@@]1 (F) -> [C@@]1(C)C[C@H](O)[C@@]1(F) (frequency 27)
# pair 890: P (=O) -> P(=O) (frequency 27)
# pair 891: O=C1 N -> O=C1N (frequency 27)
# pair 892: O. O. -> O.O. (frequency 27)
# pair 893: O C1=CC=C -> OC1=CC=C (frequency 27)
# pair 894: NC(=O)[C@H]( CC(O)=O) -> NC(=O)[C@H](CC(O)=O) (frequency 27)
# pair 895: N(CC 1 -> N(CC1 (frequency 27)
# pair 896: CCN(CC 2) -> CCN(CC2) (frequency 27)
# pair 897: CCN 2 -> CCN2 (frequency 27)
# pair 898: CC2=C N -> CC2=CN (frequency 27)
# pair 899: CC2 =C( -> CC2=C( (frequency 27)
# pair 900: C=C (CC -> C=C(CC (frequency 27)
# pair 901: C3=C2 C=CC=C3) -> C3=C2C=CC=C3) (frequency 27)
# pair 902: C1=CC=C( OC) -> C1=CC=C(OC) (frequency 27)
# pair 903: C(=O)N[C@@H]( CC(C)C) -> C(=O)N[C@@H](CC(C)C) (frequency 27)
# pair 904: C(=O)N[C@@H]( C(C)C) -> C(=O)N[C@@H](C(C)C) (frequency 27)
# pair 905: @] (=O) -> @](=O) (frequency 27)
# pair 906: =C1 O</w> -> =C1O</w> (frequency 27)
# pair 907: =C( N1C(=O)[C@H]2NC(=O) -> =C(N1C(=O)[C@H]2NC(=O) (frequency 27)
# pair 908: \C(=C / -> \C(=C/ (frequency 26)
# pair 909: [H][C@]1 2CC -> [H][C@]12CC (frequency 26)
# pair 910: [C@]3 (C) -> [C@]3(C) (frequency 26)
# pair 911: [C@@]3([H])CC [C@]12C) -> [C@@]3([H])CC[C@]12C) (frequency 26)
# pair 912: [C@@]2([H]) O)[C@]([H])(O) -> [C@@]2([H])O)[C@]([H])(O) (frequency 26)
# pair 913: [C@@]1([H]) [C@@]2([H]) -> [C@@]1([H])[C@@]2([H]) (frequency 26)
# pair 914: O C3=C( -> OC3=C( (frequency 26)
# pair 915: NC(=O)[C@H]( CC(C)C) -> NC(=O)[C@H](CC(C)C) (frequency 26)
# pair 916: CO CC -> COCC (frequency 26)
# pair 917: CN1 C=N -> CN1C=N (frequency 26)
# pair 918: CCCC C1) -> CCCCC1) (frequency 26)
# pair 919: CCC(CC 1) -> CCC(CC1) (frequency 26)
# pair 920: CC1=C( C) -> CC1=C(C) (frequency 26)
# pair 921: C2=C1 C=C( -> C2=C1C=C( (frequency 26)
# pair 922: C2=C1 C(=O) -> C2=C1C(=O) (frequency 26)
# pair 923: C2=C(N) N=C -> C2=C(N)N=C (frequency 26)
# pair 924: C1=CC=C(Cl) C=C1) -> C1=CC=C(Cl)C=C1) (frequency 26)
# pair 925: C1=CC=C (C) -> C1=CC=C(C) (frequency 26)
# pair 926: C(=O)N [C@@H]1 -> C(=O)N[C@@H]1 (frequency 26)
# pair 927: C(=O) C1=CC=CC=C1</w> -> C(=O)C1=CC=CC=C1</w> (frequency 26)
# pair 928: C \C=C\ -> C\C=C\ (frequency 26)
# pair 929: C [C@]([H])(O) -> C[C@]([H])(O) (frequency 26)
# pair 930: \C( [H]) -> \C([H]) (frequency 25)
# pair 931: [NH 3 -> [NH3 (frequency 25)
# pair 932: [H][C@@]12CC [C@](O)(C(=O) -> [H][C@@]12CC[C@](O)(C(=O) (frequency 25)
# pair 933: [H][C@@](O) (CO) -> [H][C@@](O)(CO) (frequency 25)
# pair 934: [C@@]1([H]) O -> [C@@]1([H])O (frequency 25)
# pair 935: [2 H]) -> [2H]) (frequency 25)
# pair 936: OC[C@H]1O[C@H]([C@H](O) [C@@H]1O) -> OC[C@H]1O[C@H]([C@H](O)[C@@H]1O) (frequency 25)
# pair 937: OC(=O) CCCC -> OC(=O)CCCC (frequency 25)
# pair 938: O [C@@H](C) -> O[C@@H](C) (frequency 25)
# pair 939: NC(=O)[C@H]( N) -> NC(=O)[C@H](N) (frequency 25)
# pair 940: NC(=O)[C@H]( CCCNC(N)=N) -> NC(=O)[C@H](CCCNC(N)=N) (frequency 25)
# pair 941: NC(=O)[C@H]( CCCCN) -> NC(=O)[C@H](CCCCN) (frequency 25)
# pair 942: C\C=C/ C\C=C/ -> C\C=C/C\C=C/ (frequency 25)
# pair 943: CN 3 -> CN3 (frequency 25)
# pair 944: CCCN 2 -> CCCN2 (frequency 25)
# pair 945: CC1=CC=C C=C1 -> CC1=CC=CC=C1 (frequency 25)
# pair 946: CC C1 -> CCC1 (frequency 25)
# pair 947: C=C C4=C3 -> C=CC4=C3 (frequency 25)
# pair 948: C2=C1 N -> C2=C1N (frequency 25)
# pair 949: C2=C( N -> C2=C(N (frequency 25)
# pair 950: C2=C N -> C2=CN (frequency 25)
# pair 951: C2 CC2) -> C2CC2) (frequency 25)
# pair 952: C(\ C) -> C(\C) (frequency 25)
# pair 953: C(O)=C 2) -> C(O)=C2) (frequency 25)
# pair 954: C(F) =C1</w> -> C(F)=C1</w> (frequency 25)
# pair 955: C(=O)N([H]) CC -> C(=O)N([H])CC (frequency 25)
# pair 956: C(=O)N C2=O) -> C(=O)NC2=O) (frequency 25)
# pair 957: C(=O)C=C3 CC[C@@]21[H]</w> -> C(=O)C=C3CC[C@@]21[H]</w> (frequency 25)
# pair 958: C( CO -> C(CO (frequency 25)
# pair 959: C =[N+] -> C=[N+] (frequency 25)
# pair 960: =CC=C 3 -> =CC=C3 (frequency 25)
# pair 961: =C( O -> =C(O (frequency 25)
# pair 962: =C( C=C1) -> =C(C=C1) (frequency 25)
# pair 963: ( C=C2) -> (C=C2) (frequency 25)
# pair 964: [C@]2 (O) -> [C@]2(O) (frequency 24)
# pair 965: [C@H]2 CC -> [C@H]2CC (frequency 24)
# pair 966: [C@@H](O [C@@H]2 -> [C@@H](O[C@@H]2 (frequency 24)
# pair 967: [A l -> [Al (frequency 24)
# pair 968: O P(O)(=O) -> OP(O)(=O) (frequency 24)
# pair 969: O NC(=O) -> ONC(=O) (frequency 24)
# pair 970: NC(=O) C1=CC=C -> NC(=O)C1=CC=C (frequency 24)
# pair 971: N=N \ -> N=N\ (frequency 24)
# pair 972: N(C) C(=O) -> N(C)C(=O) (frequency 24)
# pair 973: CO C1=CC=C( -> COC1=CC=C( (frequency 24)
# pair 974: CN1 CCN(CC -> CN1CCN(CC (frequency 24)
# pair 975: CC1=C N( -> CC1=CN( (frequency 24)
# pair 976: C2=CC=C 3 -> C2=CC=C3 (frequency 24)
# pair 977: C1=CC=C( NC2=N -> C1=CC=C(NC2=N (frequency 24)
# pair 978: C1=CC=C( N) -> C1=CC=C(N) (frequency 24)
# pair 979: C1=C2N=CN([C@@H]3 O[C@H](CO -> C1=C2N=CN([C@@H]3O[C@H](CO (frequency 24)
# pair 980: C1 CC -> C1CC (frequency 24)
# pair 981: C(CC ) -> C(CC) (frequency 24)
# pair 982: C(C) =C1</w> -> C(C)=C1</w> (frequency 24)
# pair 983: C(=O)N O) -> C(=O)NO) (frequency 24)
# pair 984: C [C@](O) -> C[C@](O) (frequency 24)
# pair 985: C [C@@H]2 -> C[C@@H]2 (frequency 24)
# pair 986: =C1 I</w> -> =C1I</w> (frequency 24)
# pair 987: (C# N) -> (C#N) (frequency 24)
# pair 988: \ N=C -> \N=C (frequency 23)
# pair 989: [O-] C(=O) -> [O-]C(=O) (frequency 23)
# pair 990: [C@]([H]) (CC -> [C@]([H])(CC (frequency 23)
# pair 991: [C@H](O)[C@@H](O) [C@@H]1O</w> -> [C@H](O)[C@@H](O)[C@@H]1O</w> (frequency 23)
# pair 992: [C@H]( OC) -> [C@H](OC) (frequency 23)
# pair 993: [C@@H]1 O[C@H](CO)[C@@H](O) -> [C@@H]1O[C@H](CO)[C@@H](O) (frequency 23)
# pair 994: [C@@H](O)[C@H](O) [C@H](O) -> [C@@H](O)[C@H](O)[C@H](O) (frequency 23)
# pair 995: O[C@]([H])(CO) [C@@]([H])(O)[C@]([H])(O) -> O[C@]([H])(CO)[C@@]([H])(O)[C@]([H])(O) (frequency 23)
# pair 996: OC[C@H]2 O[C@H]([C@H](O) -> OC[C@H]2O[C@H]([C@H](O) (frequency 23)
# pair 997: OCC (=O) -> OCC(=O) (frequency 23)
# pair 998: O [C@H]2 -> O[C@H]2 (frequency 23)
# pair 999: O P(O)(O)=O</w> -> OP(O)(O)=O</w> (frequency 23)
# pair 1000: O C1 -> OC1 (frequency 23)
# pair 1001: NC1=NC2=C( N=CN2 -> NC1=NC2=C(N=CN2 (frequency 23)
# pair 1002: NC1=N C=NC2=C1 -> NC1=NC=NC2=C1 (frequency 23)
# pair 1003: NC1=N C(=O)N(C=C1) -> NC1=NC(=O)N(C=C1) (frequency 23)
# pair 1004: NC(=O) [C@@H]2 -> NC(=O)[C@@H]2 (frequency 23)
# pair 1005: N1C=C C(=O)NC1=O</w> -> N1C=CC(=O)NC1=O</w> (frequency 23)
# pair 1006: N1 CCN(CC -> N1CCN(CC (frequency 23)
# pair 1007: N1 C=C( -> N1C=C( (frequency 23)
# pair 1008: N(C) C</w> -> N(C)C</w> (frequency 23)
# pair 1009: N C(N)=N -> NC(N)=N (frequency 23)
# pair 1010: CN1 C(=O)[C@H]( -> CN1C(=O)[C@H]( (frequency 23)
# pair 1011: CC1=C N=C -> CC1=CN=C (frequency 23)
# pair 1012: C2=CC=CC=C2) C=C1</w> -> C2=CC=CC=C2)C=C1</w> (frequency 23)
# pair 1013: C1=C C(O)=C(O) -> C1=CC(O)=C(O) (frequency 23)
# pair 1014: C(N)=N 1</w> -> C(N)=N1</w> (frequency 23)
# pair 1015: C(N S(=O)(=O) -> C(NS(=O)(=O) (frequency 23)
# pair 1016: C(Cl)=C 2</w> -> C(Cl)=C2</w> (frequency 23)
# pair 1017: C(=S) N -> C(=S)N (frequency 23)
# pair 1018: C(=O)N[C@@H]( CCCNC(N)=N) -> C(=O)N[C@@H](CCCNC(N)=N) (frequency 23)
# pair 1019: C(=O)N[C@@H]( CC1=CC=CC=C1) -> C(=O)N[C@@H](CC1=CC=CC=C1) (frequency 23)
# pair 1020: C(=O)N S(=O)(=O) -> C(=O)NS(=O)(=O) (frequency 23)
# pair 1021: (F)(F) F) -> (F)(F)F) (frequency 23)
# pair 1022: (CC2 =C -> (CC2=C (frequency 23)
# pair 1023: \ N=N\ -> \N=N\ (frequency 22)
# pair 1024: [P@ @](O)(=O) -> [P@@](O)(=O) (frequency 22)
# pair 1025: [H] \ -> [H]\ (frequency 22)
# pair 1026: [C@]([H])(O) [C@]([H])(O) -> [C@]([H])(O)[C@]([H])(O) (frequency 22)
# pair 1027: [C@]([H]) (N -> [C@]([H])(N (frequency 22)
# pair 1028: [C@H](O) [C@@H](C) -> [C@H](O)[C@@H](C) (frequency 22)
# pair 1029: [C@@]1(C)C[C@H](O) [C@@]1([H])[C@@]2([H])CC -> [C@@]1(C)C[C@H](O)[C@@]1([H])[C@@]2([H])CC (frequency 22)
# pair 1030: [C@@H](O) [C@H]2O) -> [C@@H](O)[C@H]2O) (frequency 22)
# pair 1031: [C@@H](O) C -> [C@@H](O)C (frequency 22)
# pair 1032: [ M -> [M (frequency 22)
# pair 1033: O[C@@]([H])(N2C=NC3=C(N)N=CN=C23) [C@]([H])(O)[C@]1([H])O</w> -> O[C@@]([H])(N2C=NC3=C(N)N=CN=C23)[C@]([H])(O)[C@]1([H])O</w> (frequency 22)
# pair 1034: OC[C@H]2O[C@H]([C@H](O) [C@@H]2O) -> OC[C@H]2O[C@H]([C@H](O)[C@@H]2O) (frequency 22)
# pair 1035: NC(=O)[C@H]( CCC(O)=O) -> NC(=O)[C@H](CCC(O)=O) (frequency 22)
# pair 1036: NC(=O)[C@H]( CC1=CC=C(O)C=C1) -> NC(=O)[C@H](CC1=CC=C(O)C=C1) (frequency 22)
# pair 1037: N1) C=C -> N1)C=C (frequency 22)
# pair 1038: CCCC N -> CCCCN (frequency 22)
# pair 1039: CCCC C) -> CCCCC) (frequency 22)
# pair 1040: CC1=C (O) -> CC1=C(O) (frequency 22)
# pair 1041: CC [C@H]1 -> CC[C@H]1 (frequency 22)
# pair 1042: C2 CCCCC2) -> C2CCCCC2) (frequency 22)
# pair 1043: C1=CC=N C=C1</w> -> C1=CC=NC=C1</w> (frequency 22)
# pair 1044: C1=C( I)C( -> C1=C(I)C( (frequency 22)
# pair 1045: C(O) =CC=C1</w> -> C(O)=CC=C1</w> (frequency 22)
# pair 1046: C(F) F) -> C(F)F) (frequency 22)
# pair 1047: C(Cl) =C2) -> C(Cl)=C2) (frequency 22)
# pair 1048: C(CC 1) -> C(CC1) (frequency 22)
# pair 1049: C( S -> C(S (frequency 22)
# pair 1050: C( =CC=C1) -> C(=CC=C1) (frequency 22)
# pair 1051: C [C@@H](O -> C[C@@H](O (frequency 22)
# pair 1052: ([O-])=O) CC -> ([O-])=O)CC (frequency 22)
# pair 1053: ( C(=O) -> (C(=O) (frequency 22)
# pair 1054: \N=C \ -> \N=C\ (frequency 21)
# pair 1055: \C( CCC -> \C(CCC (frequency 21)
# pair 1056: [Na+]. [Na+]. -> [Na+].[Na+]. (frequency 21)
# pair 1057: [NH2 +]) -> [NH2+]) (frequency 21)
# pair 1058: [NH +] -> [NH+] (frequency 21)
# pair 1059: [H][C@]1 (N) -> [H][C@]1(N) (frequency 21)
# pair 1060: [H][C@](N) (CC -> [H][C@](N)(CC (frequency 21)
# pair 1061: [H][C@@]12CC [C@@](O) -> [H][C@@]12CC[C@@](O) (frequency 21)
# pair 1062: [Fe +3]. -> [Fe+3]. (frequency 21)
# pair 1063: [C@@]3 (C) -> [C@@]3(C) (frequency 21)
# pair 1064: [C@@H](O) [C@@H]( -> [C@@H](O)[C@@H]( (frequency 21)
# pair 1065: OC[C@H]1 O -> OC[C@H]1O (frequency 21)
# pair 1066: O C(C)=O) -> OC(C)=O) (frequency 21)
# pair 1067: O C(C)(C) -> OC(C)(C) (frequency 21)
# pair 1068: NC(=O) OC) -> NC(=O)OC) (frequency 21)
# pair 1069: N=N 1) -> N=N1) (frequency 21)
# pair 1070: N=C(N) N=C2 -> N=C(N)N=C2 (frequency 21)
# pair 1071: N=C (O) -> N=C(O) (frequency 21)
# pair 1072: N1CC C(CC1) -> N1CCC(CC1) (frequency 21)
# pair 1073: N(C) C(=O)[C@H]( -> N(C)C(=O)[C@H]( (frequency 21)
# pair 1074: C[C@@H]( N) -> C[C@@H](N) (frequency 21)
# pair 1075: CS SC[C@H]( -> CSSC[C@H]( (frequency 21)
# pair 1076: CN (C)C) -> CN(C)C) (frequency 21)
# pair 1077: CCCC (=O) -> CCCC(=O) (frequency 21)
# pair 1078: CC1=C 2 -> CC1=C2 (frequency 21)
# pair 1079: CC 3 -> CC3 (frequency 21)
# pair 1080: C=C1 F</w> -> C=C1F</w> (frequency 21)
# pair 1081: C=C1 F) -> C=C1F) (frequency 21)
# pair 1082: C3=C( C=CC=C3) -> C3=C(C=CC=C3) (frequency 21)
# pair 1083: C3=C( C=C -> C3=C(C=C (frequency 21)
# pair 1084: C2=N C=C( -> C2=NC=C( (frequency 21)
# pair 1085: C2=N 1) -> C2=N1) (frequency 21)
# pair 1086: C2=CC=C (O) -> C2=CC=C(O) (frequency 21)
# pair 1087: C1CCCC 1) -> C1CCCC1) (frequency 21)
# pair 1088: C1=CC=CC=C1 Cl</w> -> C1=CC=CC=C1Cl</w> (frequency 21)
# pair 1089: C1=C N=C( -> C1=CN=C( (frequency 21)
# pair 1090: C(F) =C1) -> C(F)=C1) (frequency 21)
# pair 1091: C(F) =C(F) -> C(F)=C(F) (frequency 21)
# pair 1092: C(CC C(O)=O) -> C(CCC(O)=O) (frequency 21)
# pair 1093: C(C)=C 1) -> C(C)=C1) (frequency 21)
# pair 1094: C(=O)N CC1=CC=C(C=C1) -> C(=O)NCC1=CC=C(C=C1) (frequency 21)
# pair 1095: C(=O) CO</w> -> C(=O)CO</w> (frequency 21)
# pair 1096: 2 =C1 -> 2=C1 (frequency 21)
# pair 1097: (CC2=CC=C C=C2) -> (CC2=CC=CC=C2) (frequency 21)
# pair 1098: \C(CCC [C@]12C) -> \C(CCC[C@]12C) (frequency 20)
# pair 1099: \C(CCC[C@]12C) =C\ -> \C(CCC[C@]12C)=C\ (frequency 20)
# pair 1100: \C(CCC[C@]12C)=C\ C=C1 -> \C(CCC[C@]12C)=C\C=C1 (frequency 20)
# pair 1101: [O H -> [OH (frequency 20)
# pair 1102: [H][C@@]12 C[C@@H](C) -> [H][C@@]12C[C@@H](C) (frequency 20)
# pair 1103: [C@]([H]) (CC(C)C) -> [C@]([H])(CC(C)C) (frequency 20)
# pair 1104: [C@H]( OC(=O) -> [C@H](OC(=O) (frequency 20)
# pair 1105: [C@@]1([H]) CC -> [C@@]1([H])CC (frequency 20)
# pair 1106: [C@@] (C)(O) -> [C@@](C)(O) (frequency 20)
# pair 1107: P(O)(=O)O P(O)(=O)O -> P(O)(=O)OP(O)(=O)O (frequency 20)
# pair 1108: O[C@H](CO)[C@@H](O)[C@H](O) [C@H]2O) -> O[C@H](CO)[C@@H](O)[C@H](O)[C@H]2O) (frequency 20)
# pair 1109: OCC (O)=O) -> OCC(O)=O) (frequency 20)
# pair 1110: O [C@@]([H])(O -> O[C@@]([H])(O (frequency 20)
# pair 1111: N2C=N C3=C2 -> N2C=NC3=C2 (frequency 20)
# pair 1112: N1C=NC2=C1 N=CN=C2 -> N1C=NC2=C1N=CN=C2 (frequency 20)
# pair 1113: CO C1=CC=CC=C1 -> COC1=CC=CC=C1 (frequency 20)
# pair 1114: CCOCC 2) -> CCOCC2) (frequency 20)
# pair 1115: CC2=CC=C (O)C=C2) -> CC2=CC=C(O)C=C2) (frequency 20)
# pair 1116: CC1=N C=C( -> CC1=NC=C( (frequency 20)
# pair 1117: CC1=CC=C (O) -> CC1=CC=C(O) (frequency 20)
# pair 1118: CC(=O) CC -> CC(=O)CC (frequency 20)
# pair 1119: C=N 2</w> -> C=N2</w> (frequency 20)
# pair 1120: C3=C (O) -> C3=C(O) (frequency 20)
# pair 1121: C3 CC3) -> C3CC3) (frequency 20)
# pair 1122: C2=N C3=C( -> C2=NC3=C( (frequency 20)
# pair 1123: C2=CC=C( C=C2 -> C2=CC=C(C=C2 (frequency 20)
# pair 1124: C2=CC=C (O -> C2=CC=C(O (frequency 20)
# pair 1125: C1=N O -> C1=NO (frequency 20)
# pair 1126: C1=N N=C( -> C1=NN=C( (frequency 20)
# pair 1127: C1=N C2=CC=CC=C2 -> C1=NC2=CC=CC=C2 (frequency 20)
# pair 1128: C1=CC=CC=C1 O</w> -> C1=CC=CC=C1O</w> (frequency 20)
# pair 1129: C(F) =C2) -> C(F)=C2) (frequency 20)
# pair 1130: C(F) =C( -> C(F)=C( (frequency 20)
# pair 1131: C(=O) \C=C\ -> C(=O)\C=C\ (frequency 20)
# pair 1132: C(=O) [C@H](C) -> C(=O)[C@H](C) (frequency 20)
# pair 1133: C [C@]1([H]) -> C[C@]1([H]) (frequency 20)
# pair 1134: C [C@@]1([H]) -> C[C@@]1([H]) (frequency 20)
# pair 1135: C [C@@]([H])(O) -> C[C@@]([H])(O) (frequency 20)
# pair 1136: (O C(C)=O) -> (OC(C)=O) (frequency 20)
# pair 1137: (N) =O</w> -> (N)=O</w> (frequency 20)
# pair 1138: (CO P(O)(O)=O) -> (COP(O)(O)=O) (frequency 20)
# pair 1139: (CC C(O)=O) -> (CCC(O)=O) (frequency 20)
# pair 1140: ( C1) -> (C1) (frequency 20)
# no pair has frequency >= 20. Stopping
